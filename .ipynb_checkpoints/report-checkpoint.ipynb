# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
df=pd.read_csv('LS_2.0.csv')

# %%
df1=df[df['PARTY']!='NOTA']
df.head()
# Out:
#            STATE CONSTITUENCY                   NAME  WINNER PARTY SYMBOL  \
# 0      Telangana     ADILABAD         SOYAM BAPU RAO       1   BJP  Lotus
# 1      Telangana     ADILABAD           Godam Nagesh       0   TRS    Car
# 2      Telangana     ADILABAD          RATHOD RAMESH       0   INC   Hand
# 3      Telangana     ADILABAD                   NOTA       0  NOTA    NaN
# 4  Uttar Pradesh         AGRA  Satyapal Singh Baghel       1   BJP  Lotus
#
#   GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# 0   MALE              52  52.0       ST      12th Pass
# 1   MALE               0  54.0       ST  Post Graduate
# 2   MALE               3  52.0       ST      12th Pass
# 3    NaN             NaN   NaN      NaN            NaN
# 4   MALE               5  58.0       SC      Doctorate
#
#                         ASSETS                  LIABILITIES  GENERAL\nVOTES  \
# 0    Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+          376892
# 1  Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+          318665
# 2  Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+          314057
# 3                          NaN                          NaN           13030
# 4  Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+          644459
#
#    POSTAL\nVOTES  TOTAL\nVOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0            482        377374                              25.330684
# 1            149        318814                              21.399929
# 2            181        314238                              21.092771
# 3              6         13036                               0.875023
# 4           2416        646875                              33.383823
#
#    OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                  35.468248         1489790
# 1                                  29.964370         1489790
# 2                                  29.534285         1489790
# 3                                   1.225214         1489790
# 4                                  56.464615         1937690

# %% [markdown]
# ## Lets see the top 5 constituency with most candidates

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='CONSTITUENCY',data=df,order=df.CONSTITUENCY.value_counts().iloc[:5].index)
plt.ylabel('No of Candidates')
plt.show()

# %% [markdown]
# ## Top 5 Parties with number of candidates

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='PARTY',data=df1,order=df1.PARTY.value_counts().iloc[:5].index,palette='gist_earth')
plt.ylabel('No of Candidates')
plt.show()

# %% [markdown]
# ## Total Number of candidates w.r.t Gender

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='GENDER',data=df1,palette='coolwarm')
plt.ylabel('No of Candidates')
plt.show()

# %% [markdown]
# #### We see there is a large gender bias in the number of candidates in our country

# %% [markdown]
# ## Top 5 Candidates with highest number of votes and their education levels

# %%
yt=np.arange(0,61,5)
df3=df1.copy()
df3.sort_values(by='Vote Percent',axis=0,ascending=False,inplace=True)
df3=df3.head(5)
plt.figure(figsize=(15,7))
sns.barplot(x='NAME',y='Vote Percent',data=df3,hue='EDUCATION',dodge=False)
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.yticks(yt)
plt.xlabel('')
plt.show()

# %% [markdown]
# ## Top Candidates With Highest number of Criminal Cases

# %%
df['CRIMINAL\nCASES'].replace(['Not Available',np.nan],'0',inplace=True)
df['CRIMINAL\nCASES']=df['CRIMINAL\nCASES'].astype(float)
df3=df.copy()
df3.sort_values('CRIMINAL\nCASES',axis=0,ascending=False,inplace=True)
df3=df3.head()
plt.figure(figsize=(16,8))
sns.barplot(x='NAME',y='CRIMINAL\nCASES',data=df3,palette='magma_r',hue='PARTY',dodge=False)
plt.yticks(np.arange(0,281,40))
plt.show()

# %% [markdown]
# ## Candidates With Highest Assets

# %%
## cleaning data for assets column
df['ASSETS'].replace(['Not Available','Nil',np.nan,'`','Telangana'],'0',inplace=True)
a=df['ASSETS'].apply(lambda x:x.split()[1] if len(x.split())>1 else x.split()[0])
b=a.apply(lambda x:x.split(','))
c=b.apply(lambda x:''.join(x))
df['ASSETS']=c
df['ASSESTS']=df['ASSETS'].astype(int)

# %%
plt.figure(figsize=(16,8))
top=df.sort_values('ASSETS',ascending=False).head()
sns.barplot(x='NAME',y='ASSETS',data=top,palette='magma_r')
plt.show()
